# %% [markdown]
# ## DS2000 & DS2001 Programming with Data & Practicum
# # Homework 3: Table Manipulation and Visualization
#
# ###  61 Points
#
# ## Due Friday, February 2 by 10:00PM

# %% [markdown]
# **Reading**:
# * [Chapter 6: Tables](https://www.inferentialthinking.com/chapters/06/Tables.html)
# * [Chapter 7: Visualization](https://www.inferentialthinking.com/chapters/07/Visualization.html)
#
#
# **Helpful Resource**:
#
# * [Python Reference](http://data8.org/fa21/python-reference.html): Cheat sheet of helpful array & table methods used in DS2000!
#
# <span style="color:green">**Note: This homework autograding tests do only a preliminary check. That means even though tests may say 100% passed, it doesn't mean your final grade will be 100%. We will be checking your submission for correctness during grading.**</span>

# %%
# Don't change this cell; just run it.
import numpy as np
from datascience import *

import otter
grader = otter.Notebook("hw03.ipynb")

# These lines do some fancy plotting magic.
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## 1. Unemployment

# %% [markdown]
# The Federal Reserve Bank of St. Louis publishes data about jobs in the US.  Below, we've loaded data on unemployment in the United States. There are many ways of defining unemployment, and our dataset includes two notions of the unemployment rate:
#
# 1. Among people who are able to work and are looking for a full-time job, the percentage who can't find a job.  This is called the *Non-Employment Index*, or *NEI*.
# 2. Among people who are able to work and are looking for a full-time job, the percentage who can't find any job *or* are only working at a part-time job.  The latter group is called *"Part-Time for Economic Reasons"*, so the acronym for this index is *NEI-PTER*.
#
# The source of the data is [here](https://fred.stlouisfed.org/categories/33509).

# %% [markdown]
# **Question 1.1 (1 pt)** The data is in a CSV file called `unemployment.csv`.  Load that file into a table called `unemployment`.

# %%
unemployment =  Table.read_table("unemployment.csv") #... 
unemployment
# Out:
# Date       | NEI     | NEI-PTER
# 1994-01-01 | 10.0974 | 11.172
# 1994-04-01 | 9.6239  | 10.7883
# 1994-07-01 | 9.3276  | 10.4831
# 1994-10-01 | 9.1071  | 10.2361
# 1995-01-01 | 8.9693  | 10.1832
# 1995-04-01 | 9.0314  | 10.1071
# 1995-07-01 | 8.9802  | 10.1084
# 1995-10-01 | 8.9932  | 10.1046
# 1996-01-01 | 9.0002  | 10.0531
# 1996-04-01 | 8.9038  | 9.9782
# ... (80 rows omitted)

# %%
grader.check("q11")
# Out:
# q11 results: All test cases passed!

# %% [markdown]
# **Question 1.2. (3 pts)** Sort the data in table `unemployment` in descending order by NEI, naming the sorted table `by_nei`.  Create another table called `by_nei_pter` that's sorted in descending order by NEI-PTER instead.

# %%
by_nei = unemployment.sort("NEI",descending=True) #...
by_nei_pter = unemployment.sort("NEI-PTER",descending=True) #...

# %%
grader.check("q12")
# Out:
# q12 results: All test cases passed!

# %% [markdown]
# **Question 1.3. (2 pts)** Use `take` (see [Selecting Rows](https://www.inferentialthinking.com/chapters/06/2/Selecting_Rows.html)) to make a table containing the data for the 10 quarters when NEI was greatest (i.e., the first 10 rows).  Call that table `greatest_nei`.
#
# `greatest_nei` should be sorted in descending order of `NEI`. Note that each row of `unemployment` represents a quarter.

# %%
greatest_nei = by_nei.take(np.arange(10)) #...
greatest_nei
# Out:
# Date       | NEI     | NEI-PTER
# 2009-10-01 | 10.9698 | 12.8557
# 2010-01-01 | 10.9054 | 12.7311
# 2009-07-01 | 10.8089 | 12.7404
# 2009-04-01 | 10.7082 | 12.5497
# 2010-04-01 | 10.6597 | 12.5664
# 2010-10-01 | 10.5856 | 12.4329
# 2010-07-01 | 10.5521 | 12.3897
# 2011-01-01 | 10.5024 | 12.3017
# 2011-07-01 | 10.4856 | 12.2507
# 2011-04-01 | 10.4409 | 12.247

# %%
grader.check("q13")
# Out:
# q13 results: All test cases passed!

# %% [markdown]
# **Question 1.4. (4 pts)** First, create an array `pter` which is the percentage of people who work part-time but are looking full-time jobs (basically pter is NEI-PTER - NEI).  Second add `pter` as a column to `unemployment` (named "PTER") and sort the resulting table by that column in descending order.  Call the table `by_pter`.
#
# *Hint:* Table 1 below displays the expected output.

# %%
pter = unemployment.column("NEI-PTER") - unemployment.column("NEI") #...
by_pter =  unemployment.with_column("PTER", pter).sort("PTER", descending=True) #...
by_pter
# Out:
# Date       | NEI     | NEI-PTER | PTER
# 2009-07-01 | 10.8089 | 12.7404  | 1.9315
# 2010-04-01 | 10.6597 | 12.5664  | 1.9067
# 2009-10-01 | 10.9698 | 12.8557  | 1.8859
# 2010-10-01 | 10.5856 | 12.4329  | 1.8473
# 2009-04-01 | 10.7082 | 12.5497  | 1.8415
# 2010-07-01 | 10.5521 | 12.3897  | 1.8376
# 2010-01-01 | 10.9054 | 12.7311  | 1.8257
# 2011-04-01 | 10.4409 | 12.247   | 1.8061
# 2011-01-01 | 10.5024 | 12.3017  | 1.7993
# 2011-10-01 | 10.3287 | 12.1214  | 1.7927
# ... (80 rows omitted)

# %%
grader.check("q14")
# Out:
# q14 results: All test cases passed!

# %% [markdown]
# Table 1
#
# <img src="Q1.4_table.PNG"/>

# %% [markdown]
# **Question 1.5. (4 pts)** Create a line plot of the PTER over time.
#
# To do this, create a new table called `pter_over_time` that adds the `year` array and the `pter` array to the `unemployment` table. Label these columns `Year` and `PTER`. Then, generate a line plot using one of the table plot methods you've learned in class.
#
# *Hint:*  Graph 1 below displays the expected output.

# %%
# The year array 
year = 1994 + np.arange(by_pter.num_rows)/4

# create the pter_over_time table
pter_over_time = unemployment.with_columns("Year", year, "PTER", pter) #...

# plot Year in the x-axis and PTER in the y-axis 
pter_over_time.plot("Year", "PTER") #...

# %%
grader.check("q15")
# Out:
# q15 results: All test cases passed!

# %% [markdown]
# Graph 1
# <img src="Q1.5_graph.PNG"/>

# %% [markdown]
# ## 2. Birth Rates

# %% [markdown]
# The following table gives census-based population estimates for each state on both July 1, 2015 and July 1, 2016. The last four columns describe the components of the estimated change in population during this time interval. **For all questions below, assume that the word "states" refers to all 52 rows including Puerto Rico & the District of Columbia.**
#
# The data was taken from [here](http://www2.census.gov/programs-surveys/popest/datasets/2010-2016/national/totals/nst-est2016-alldata.csv).
#
# If you want to read more about the different column descriptions, click [here](http://www2.census.gov/programs-surveys/popest/datasets/2010-2015/national/totals/nst-est2015-alldata.pdf)!
#
# The raw data is a bit messy - run the cell below to clean the table and make it easier to work with.

# %%
# Don't change this cell; just run it.
pop = Table.read_table('nst-est2016-alldata.csv').where('SUMLEV', 40).select([1, 4, 12, 13, 27, 34, 62, 69])
pop = pop.relabeled('POPESTIMATE2015', '2015').relabeled('POPESTIMATE2016', '2016')
pop = pop.relabeled('BIRTHS2016', 'BIRTHS').relabeled('DEATHS2016', 'DEATHS')
pop = pop.relabeled('NETMIG2016', 'MIGRATION').relabeled('RESIDUAL2016', 'OTHER')
pop = pop.with_columns("REGION", np.array([int(region) if region != "X" else 0 for region in pop.column("REGION")]))
pop.set_format([2, 3, 4, 5, 6, 7], NumberFormatter(decimals=0)).show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>REGION</th> <th>NAME</th> <th>2015</th> <th>2016</th> <th>BIRTHS</th> <th>DEATHS</th> <th>MIGRATION</th> <th>OTHER</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>3     </td> <td>Alabama   </td> <td>4,853,875 </td> <td>4,863,300 </td> <td>58,556 </td> <td>52,405 </td> <td>3,874    </td> <td>-600  </td>
#         </tr>
#         <tr>
#             <td>4     </td> <td>Alaska    </td> <td>737,709   </td> <td>741,894   </td> <td>11,255 </td> <td>4,511  </td> <td>-2,557   </td> <td>-2    </td>
#         </tr>
#         <tr>
#             <td>4     </td> <td>Arizona   </td> <td>6,817,565 </td> <td>6,931,071 </td> <td>87,204 </td> <td>56,564 </td> <td>76,405   </td> <td>6,461 </td>
#         </tr>
#         <tr>
#             <td>3     </td> <td>Arkansas  </td> <td>2,977,853 </td> <td>2,988,248 </td> <td>37,936 </td> <td>30,581 </td> <td>3,530    </td> <td>-490  </td>
#         </tr>
#         <tr>
#             <td>4     </td> <td>California</td> <td>38,993,940</td> <td>39,250,017</td> <td>502,848</td> <td>273,850</td> <td>33,530   </td> <td>-6,451</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (47 rows omitted)</p>

# %% [markdown]
# In the table pop, a positive MiGRATION refers to people moving into the state, a negative MIGRATION refers to people moving out of the state.

# %% [markdown]
# **Question 2.1. (2pts)** Assign `us_birth_rate` to the total US annual birth rate during this time interval. The annual birth rate is the total number of births in that period divided by the population size at the start of the time period.
#
# *Hint:* Alabama has birth rate of 58,556/4,853,875 = 0.012

# %%
us_birth_rate = sum(pop.column('BIRTHS'))/sum(pop.column('2015')) # ...
us_birth_rate
# Out:
# 0.012358536498646102

# %%
grader.check("q21")
# Out:
# q21 results: All test cases passed!

# %% [markdown]
# **Question 2.2.(a) (2 pts)** Add a `Migration-Rate` column to the table `pop` that contains the **annual rate of migration** for each state.
#
# The annual rate of migration for a year-long period is the net number of migrations divided by the population size at the start of the period.
#
# *Hint:* The annual rate of migration in Alabama is 3,874 / 4,853,875 = 0.0000798125. Table 2 displays the expected output.

# %%
migration_rates = pop.with_column('Migration-Rate', pop.column('MIGRATION')/pop.column('2015')) #...
migration_rates
# Out:
# REGION | NAME                 | 2015       | 2016       | BIRTHS  | DEATHS  | MIGRATION | OTHER  | Migration-Rate
# 3      | Alabama              | 4,853,875  | 4,863,300  | 58,556  | 52,405  | 3,874     | -600   | 0.000798125
# 4      | Alaska               | 737,709    | 741,894    | 11,255  | 4,511   | -2,557    | -2     | -0.00346614
# 4      | Arizona              | 6,817,565  | 6,931,071  | 87,204  | 56,564  | 76,405    | 6,461  | 0.0112071
# 3      | Arkansas             | 2,977,853  | 2,988,248  | 37,936  | 30,581  | 3,530     | -490   | 0.00118542
# 4      | California           | 38,993,940 | 39,250,017 | 502,848 | 273,850 | 33,530    | -6,451 | 0.000859877
# 4      | Colorado             | 5,448,819  | 5,540,545  | 67,453  | 37,121  | 60,773    | 621    | 0.0111534
# 1      | Connecticut          | 3,584,730  | 3,576,452  | 35,848  | 30,638  | -12,822   | -666   | -0.00357684
# 3      | Delaware             | 944,076    | 952,065    | 10,922  | 8,945   | 5,583     | 429    | 0.00591372
# 3      | District of Columbia | 670,377    | 681,170    | 9,779   | 5,455   | 6,392     | 77     | 0.00953493
# 3      | Florida              | 20,244,914 | 20,612,439 | 222,793 | 201,485 | 325,986   | 20,231 | 0.0161021
# ... (42 rows omitted)

# %%
grader.check("q22a")
# Out:
# q22a results: All test cases passed!

# %% [markdown]
# Table 2
#
# <img src="Q2.2_table.PNG"/>

# %% [markdown]
# **Question 2.2.(b) (2 pts)** Assign `highest_migration_rate_state` to the state wuth the highest migration rate.

# %%
highest_migration_rate_state =  migration_rates.sort('Migration-Rate', descending=True).column('NAME').item(0) #...
highest_migration_rate_state
# Out:
# 'Florida'

# %%
grader.check("q22b")
# Out:
# q22b results: All test cases passed!

# %% [markdown]
# **Question 2.3. (4 pts)** Assign `west_births` to the total number of births that occurred in region 4 (the Western US).

# %%
# filter the rows with a value 4 in the region column 
region_4  = pop.where('REGION', are.equal_to(4)) #...

# sum all the values in the column BIRTHS in the new table region_4
west_births = sum(region_4.column('BIRTHS')) #... 

west_births
# Out:
# 979657

# %%
grader.check("q23")
# Out:
# q23 results: All test cases passed!

# %% [markdown]
# **Question 2.4. (4 pts)** Assign `less_than_west_births` to the number of states that had a total population in 2016 that was smaller than the *total number of births in region 4 (the Western US)* during this time interval.

# %%
# filter the rows in pop with a population in 2016 less than the value west_births
less_than_west_births = pop.where('2016', are.below(west_births)) #...

# calculate the number of rows in less_than_west_births 
num_of_states = less_than_west_births.num_rows #...
num_of_states
# Out:
# 7

# %%
grader.check("q24")
# Out:
# q24 results: All test cases passed!

# %% [markdown]
# **Question 2.5. (2 pts)** In the next question, you will be creating a visualization to understand the relationship between birth and death rates. The annual death rate for a year-long period is the total number of deaths in that period divided by the population size at the start of the time period.
#
# What visualization is most appropriate to see if there is an association between birth and death rates during a given time interval?
#
# 1. Line Graph
# <br>
# 2. Scatter Plot
# <br>
# 3. Bar Chart
#
# Assign `visualization` below to the number corresponding to the correct visualization.

# %%
visualization = 2 #...

# %%
grader.check("q25")
# Out:
# q25 results: All test cases passed!

# %% [markdown]
# **Question 2.6. (4 pts)**  Add two columns, `Birth Rate` and `Death Rate` to the `pop` table, where the annual birth rate for a year is the number of births in a year divided by the population size at the start of the year (so 2015).

# %%
# first, add a column Birth Rate to the pop table
pop =  pop.with_columns("Birth Rate", pop.column('BIRTHS')/pop.column('2015')) #...

# second, add a column Death Rate to the pop table
pop = pop.with_columns("Death Rate", pop.column('DEATHS')/pop.column('2015')) #... 
pop
# Out:
# REGION | NAME                 | 2015       | 2016       | BIRTHS  | DEATHS  | MIGRATION | OTHER  | Birth Rate | Death Rate
# 3      | Alabama              | 4,853,875  | 4,863,300  | 58,556  | 52,405  | 3,874     | -600   | 0.0120638  | 0.0107965
# 4      | Alaska               | 737,709    | 741,894    | 11,255  | 4,511   | -2,557    | -2     | 0.0152567  | 0.00611488
# 4      | Arizona              | 6,817,565  | 6,931,071  | 87,204  | 56,564  | 76,405    | 6,461  | 0.0127911  | 0.0082968
# 3      | Arkansas             | 2,977,853  | 2,988,248  | 37,936  | 30,581  | 3,530     | -490   | 0.0127394  | 0.0102695
# 4      | California           | 38,993,940 | 39,250,017 | 502,848 | 273,850 | 33,530    | -6,451 | 0.0128955  | 0.00702289
# 4      | Colorado             | 5,448,819  | 5,540,545  | 67,453  | 37,121  | 60,773    | 621    | 0.0123794  | 0.00681267
# 1      | Connecticut          | 3,584,730  | 3,576,452  | 35,848  | 30,638  | -12,822   | -666   | 0.0100002  | 0.00854681
# 3      | Delaware             | 944,076    | 952,065    | 10,922  | 8,945   | 5,583     | 429    | 0.011569   | 0.00947487
# 3      | District of Columbia | 670,377    | 681,170    | 9,779   | 5,455   | 6,392     | 77     | 0.0145873  | 0.00813721
# 3      | Florida              | 20,244,914 | 20,612,439 | 222,793 | 201,485 | 325,986   | 20,231 | 0.0110049  | 0.00995238
# ... (42 rows omitted)

# %% [markdown]
# **Question 2.7. (2 pts)**  Show a table with seven states having the lowest death rates.

# %%
pop.sort('Death Rate').take(np.arange(7)) #...
# Out:
# REGION | NAME       | 2015       | 2016       | BIRTHS  | DEATHS  | MIGRATION | OTHER  | Birth Rate | Death Rate
# 4      | Utah       | 2,990,632  | 3,051,217  | 51,444  | 16,447  | 25,412    | 176    | 0.0172017  | 0.00549951
# 4      | Alaska     | 737,709    | 741,894    | 11,255  | 4,511   | -2,557    | -2     | 0.0152567  | 0.00611488
# 4      | Colorado   | 5,448,819  | 5,540,545  | 67,453  | 37,121  | 60,773    | 621    | 0.0123794  | 0.00681267
# 4      | California | 38,993,940 | 39,250,017 | 502,848 | 273,850 | 33,530    | -6,451 | 0.0128955  | 0.00702289
# 3      | Texas      | 27,429,639 | 27,862,596 | 404,533 | 192,814 | 217,542   | 3,696  | 0.014748   | 0.0070294
# 4      | Idaho      | 1,652,828  | 1,683,140  | 22,792  | 12,496  | 18,869    | 1,147  | 0.0137897  | 0.00756038
# 2      | Minnesota  | 5,482,435  | 5,519,952  | 69,190  | 41,938  | 11,882    | -1,617 | 0.0126203  | 0.00764952

# %% [markdown]
# **Question 2.8. (2 pts)**  In the code cell below, create a visualization that will help us determine if there is an association between birth rate and death rate during this time interval.

# %%
# visualization 
pop.scatter("Birth Rate", "Death Rate") #...

# %% [markdown]
# **Question 2.9. (1 pt)** `True` or `False`: There is an association between birth rate and death rate during this time interval.
#
# Assign `assoc` to `True` or `False` in the cell below.

# %%
assoc = True #...

# %%
grader.check("q29")
# Out:
# q29 results: All test cases passed!

# %% [markdown]
# ## 3. Uber

# %% [markdown]
# Below we load two tables containing 200,000 weekday Uber rides in the Manila, Philippines, and Boston, Massachusetts metropolitan areas from the [Uber Movement](https://movement.uber.com) project. The `sourceid` and `dstid` columns contain codes corresponding to start and end locations of each ride. The `hod` column contains codes corresponding to the hour of the day the ride took place. The `ride time` column contains the length of the ride, in minutes.

# %%
boston = Table.read_table("boston.csv")
manila = Table.read_table("manila.csv")
print("Boston Table")
boston.show(4)
print("Manila Table")
manila.show(4)
# Out:
# Boston Table
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>sourceid</th> <th>dstid</th> <th>hod</th> <th>ride time</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>584     </td> <td>33   </td> <td>7   </td> <td>11.866   </td>
#         </tr>
#         <tr>
#             <td>1013    </td> <td>1116 </td> <td>13  </td> <td>17.7993  </td>
#         </tr>
#         <tr>
#             <td>884     </td> <td>1190 </td> <td>22  </td> <td>19.3488  </td>
#         </tr>
#         <tr>
#             <td>211     </td> <td>364  </td> <td>1   </td> <td>1.7235   </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (199996 rows omitted)</p>
# Manila Table
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>sourceid</th> <th>dstid</th> <th>hod</th> <th>ride time</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>544     </td> <td>5    </td> <td>22  </td> <td>22.8115  </td>
#         </tr>
#         <tr>
#             <td>302     </td> <td>240  </td> <td>21  </td> <td>7.02267  </td>
#         </tr>
#         <tr>
#             <td>278     </td> <td>99   </td> <td>16  </td> <td>21.6437  </td>
#         </tr>
#         <tr>
#             <td>720     </td> <td>775  </td> <td>18  </td> <td>13.0597  </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (199996 rows omitted)</p>

# %% [markdown]
# **Question 3.1. (3 pts)** Assign `bos_avg` and `manila_avg`to be the average ride time for Boston rides and Manila rides, respectively.

# %%
bos_avg = np.average(boston.column('ride time')) #...
print('Boston average ride time is ', bos_avg) 
manila_avg = np.average(manila.column('ride time')) #...
print('Manila average ride time is ', manila_avg)
# Out:
# Boston average ride time is  16.50247791
# Manila average ride time is  33.743241755

# %%
grader.check("q31")
# Out:
# q31 results: All test cases passed!

# %% [markdown]
# **Question 3.2. (2 pts)** Now let's look at the distribution of the ride times. Produce histograms of all ride times in Boston using the given bins.

# %%
equal_bins = np.arange(0, 120, 5)
boston.select("ride time").hist(bins = equal_bins) #...

# %% [markdown]
# **Question 3.3. (2 pts)** Now, produce histograms of all ride times in Manila using the given bins.

# %%
manila.select("ride time").hist(bins = equal_bins) #...

# Don't delete the following line!
plots.ylim(0, 0.05)
# Out:
# (0.0, 0.05)

# %% [markdown]
# **Question 3.4. (1 pts)** Let's take a closer look at the y-axis label. Assign `unit_meaning` to an integer (1, 2, 3) that corresponds to the "unit" in "Percent per unit".
#
# 1. minute
# 2. ride time
# 3. second

# %%
unit_meaning = 1 #...
unit_meaning
# Out:
# 1

# %%
grader.check("q34")
# Out:
# q34 results: All test cases passed!

# %% [markdown]
# **Question 3.5. (4 pts)** Assign `boston_under_15` and `manila_under_15` to the percentage of rides that are less than 15 minutes in their respective metropolitan areas. Use the height variables provided below in order to compute the percentages. Recall that percentages are areas, and area = width * height.  Your solution should only use height variables, numbers, and mathematical operations. You should **not** access the tables `boston` and `manila` in any way.

# %%
boston_under_5_height = 1.2
manila_under_5_height = 0.6
boston_5_to_under_10_height = 3.2
manila_5_to_under_10_height = 1.4
boston_10_to_under_15_height = 4.9
manila_10_to_under_15_height = 2.2

boston_under_15 = 5*(1.2+3.2+4.9) # ...
manila_under_15 = 5*(0.6+1.4+2.2) # ...

boston_under_15, manila_under_15
# Out:
# (46.5, 21.0)

# %%
grader.check("q35")
# Out:
# q35 results: All test cases passed!

# %% [markdown]
# **Question 3.6. (2 pts)** Let's take a closer look at the distribution of ride times in Boston. Assign `boston_median_bin` to an integer (1, 2, 3, or 4) that corresponds to the bin that contains the median time.
#
# 1. 0-8 minutes
# 2. 8-14 minutes
# 3. 14-20 minutes
# 4. 20-40 minutes
#
# *Hint:* The median of a sorted list has half of the list elements to its left, and half to its right.

# %%
boston_median_bin = 3 # ...
boston_median_bin
# Out:
# 3

# %%
grader.check("q36")
# Out:
# q36 results: All test cases passed!

# %% [markdown]
# ## 4. Histograms

# %% [markdown]
# Consider the following scatter plot:
#
# ![](scatter.png)
#
# The axes of the plot represent values of two variables: $x$ and $y$.

# %% [markdown]
# Suppose we have a table called `t` that has two columns in it:
#
# - `x`: a column containing the x-values of the points in the scatter plot
# - `y`: a column containing the y-values of the points in the scatter plot

# %% [markdown]
# Below, you are given three histograms—one corresponds to column `x`, one corresponds to column `y`, and one does not correspond to either column.

# %% [markdown]
# **Histogram A:**
#
# ![](var3.png)
#
# **Histogram B:**
#
# ![](var1.png)
#
# **Histogram C:**
#
# ![](var2.png)

# %% [markdown]
# **Question 4.1. (1 pts)** Suppose we run `t.hist('x')`. Which histogram does this code produce? Assign `histogram_column_x` to either 1, 2, or 3.
#
# 1. Histogram A
# 2. Histogram B
# 3. Histogram C

# %%
histogram_column_x = 3 #...

# %%
grader.check("q41")
# Out:
# q41 results: All test cases passed!

# %% [markdown]
# **Question 4.2. (3 pts)** State at least one reason why you chose the histogram from Question 4.1. **Make sure to clearly indicate which histogram you selected** (ex: "I chose histogram A because ...").

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# **Question 4.3. (1 pts)** Suppose we run `t.hist('y')`. Which histogram does this code produce? Assign `histogram_column_y` to either 1, 2, or 3.
#
# 1. Histogram A
# 2. Histogram B
# 3. Histogram C

# %%
histogram_column_y = 2 #...

# %%
grader.check("q43")
# Out:
# q43 results: All test cases passed!

# %% [markdown]
# **Question 4.4. (3 pts)** State at least one reason why you chose the histogram from Question 4.3. **Make sure to clearly indicate which histogram you selected** (ex: "I chose histogram A because ...").

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# ---
#
# To double-check your work, the cell below will rerun all of the autograder tests.

# %%
grader.check_all()
# Out:
# q11 results: All test cases passed!
#
# q12 results: All test cases passed!
#
# q13 results: All test cases passed!
#
# q14 results: All test cases passed!
#
# q15 results: All test cases passed!
#
# q21 results: All test cases passed!
#
# q22a results: All test cases passed!
#
# q22b results: All test cases passed!
#
# q23 results: All test cases passed!
#
# q24 results: All test cases passed!
#
# q25 results: All test cases passed!
#
# q29 results: All test cases passed!
#
# q31 results: All test cases passed!
#
# q34 results: All test cases passed!
#
# q35 results: All test cases passed!
#
# q36 results: All test cases passed!
#
# q41 results: All test cases passed!
#
# q43 results: All test cases passed!

# %% [markdown]
# <br><br>
# **You've completed Homework 3!**
#
# Please **save** your notebook, **download** a pdf version of the notebook, and **submit** it to Gradescope.
